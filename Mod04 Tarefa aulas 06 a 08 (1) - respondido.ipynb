# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio"
dados = requests.get(url)
dados.status_code
# Out:
# 200

# %%
# 2) Seu código aqui
dados_json = dados.json()
dados_json.keys()
# Out:
# dict_keys(['items', 'hasMore', 'limit', 'offset', 'count', 'links'])

# %%
# 3) Seu código aqui
df = pd.DataFrame(dados_json['items'])
df
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        60039        Município      Petrópolis   3303906  RJ
# 1         5275        Município  Rio de Janeiro   3304557  RJ
# 2         5618        Município     Nova Iguaçu   3303500  RJ
# 3         6981        Município  Rio de Janeiro   3304557  RJ
# 4        61653        Município     Teresópolis   3305802  RJ
# ..         ...              ...             ...       ...  ..
# 246      10412        Município          Maricá   3302700  RJ
# 247       9234        Município   Nova Friburgo   3303401  RJ
# 248      13579        Município  Rio de Janeiro   3304557  RJ
# 249      13753        Município           Piraí   3304003  RJ
# 250       8839        Município     Porciúncula   3304102  RJ
#
#                   num_pvl                                             status  \
# 0    PVL02.005942/2022-88                                           Deferido
# 1                    None  Encaminhado à PGFN com manifestação técnica fa...
# 2                    None                                          Arquivado
# 3                    None                                           Deferido
# 4    PVL02.007127/2022-53                                           Deferido
# ..                    ...                                                ...
# 246                  None                     Arquivado por decurso de prazo
# 247                  None                                           Deferido
# 248                  None                                          Arquivado
# 249                  None                                           Deferido
# 250                  None                                          Arquivado
#
#              num_processo        data_protocolo  \
# 0    17944.102384/2022-61  2022-06-21T13:12:44Z
# 1    17944.000075/2014-47  2014-04-01T03:00:00Z
# 2    17944.000156/2010-13  2010-12-03T02:00:00Z
# 3    17944.000472/2007-90  2007-04-30T03:00:00Z
# 4    17944.103775/2022-01  2022-10-19T19:18:08Z
# ..                    ...                   ...
# 246  17944.001193/2011-20  2012-09-12T03:00:00Z
# 247  17944.000933/2013-72  2013-08-30T03:00:00Z
# 248  19405.000029/2006-61  2006-07-20T03:00:00Z
# 249  19405.000071/2002-58  2002-09-30T03:00:00Z
# 250  17944.000850/2008-16  2008-09-01T03:00:00Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1    Operação contratual interna (com garantia da U...
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4                          Operação contratual interna
# ..                                                 ...
# 246                        Operação contratual interna
# 247                        Operação contratual interna
# 248                        Operação contratual interna
# 249                        Operação contratual interna
# 250                        Operação contratual interna
#
#                                             finalidade  \
# 0                                       Infraestrutura
# 1                                       Infraestrutura
# 2                            PAC - Saneamento - 2009 A
# 3                                    Saneamento básico
# 4                                       Multissetorial
# ..                                                 ...
# 246  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 247                                            Provias
# 248                                  Saneamento básico
# 249                                               PMAT
# 250                                Caminho da Escola 2
#
#                          tipo_credor  \
# 0    Instituição Financeira Nacional
# 1    Instituição Financeira Nacional
# 2    Instituição Financeira Nacional
# 3    Instituição Financeira Nacional
# 4    Instituição Financeira Nacional
# ..                               ...
# 246  Instituição Financeira Nacional
# 247  Instituição Financeira Nacional
# 248  Instituição Financeira Nacional
# 249  Instituição Financeira Nacional
# 250  Instituição Financeira Nacional
#
#                                                 credor moeda         valor  \
# 0                              Caixa Econômica Federal  Real  2.000000e+07
# 1    Banco Nacional de Desenvolvimento Econômico e ...  Real  2.715389e+09
# 2                              Caixa Econômica Federal  Real  6.073730e+07
# 3                              Caixa Econômica Federal  Real  7.403640e+06
# 4       Agência de Fomento do Estado do Rio de Janeiro  Real  3.500000e+07
# ..                                                 ...   ...           ...
# 246                            Caixa Econômica Federal  Real  2.280000e+07
# 247                                Banco do Brasil S/A  Real  1.400000e+07
# 248                            Caixa Econômica Federal  Real  1.316494e+06
# 249  Banco Nacional de Desenvolvimento Econômico e ...  Real  4.086000e+05
# 250                                Banco do Brasil S/A  Real  1.455000e+05
#
#      pvl_assoc_divida  pvl_contradado_credor data_status
# 0                   0                      1  23/06/2022
# 1                   1                      0  29/05/2014
# 2                   0                      0  15/12/2010
# 3                   1                      0  25/05/2007
# 4                   0                      0  21/10/2022
# ..                ...                    ...         ...
# 246                 0                      0  17/10/2012
# 247                 1                      0  09/10/2013
# 248                 0                      0  26/06/2007
# 249                 0                      0  11/10/2002
# 250                 0                      0  13/11/2008
#
# [251 rows x 18 columns]

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def Pega_Dados_API(UF, Interessado):
    if (type(Interessado) != str | type(UF) != str):
        print("Os dados devem ser fornecidos no formato string.")
        return
    UF = UF.upper()    
    Interessado = Interessado.capitalize()
 
    if (Interessado == "Estado") | (Interessado == "Município"):
        pass
    elif Interessado == "Municipio":
        Interessado = "Município"
    else:
        print("O campo 'Interessado' deve ser 'Estado' ou 'Município'")
              
    url=f"http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={UF}&tipo_interessado={Interessado}"
    dados = requests.get(url)
    dados_json = dados.json()
    df = pd.DataFrame(dados_json['items'])    
              
    return df

# %%
Pega_Dados_API('ce', 'municipio')
# Out:
#      id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0         7751        Município    Barbalha   2301901  CE
# 1        60529        Município   Paraipaba   2310258  CE
# 2        64661        Município   Fortaleza   2304400  CE
# 3         5338        Município     Iracema   2306009  CE
# 4         4983        Município   Fortaleza   2304400  CE
# ..         ...              ...         ...       ...  ..
# 286      38939        Município      Sobral   2312908  CE
# 287      24129        Município   Fortaleza   2304400  CE
# 288      13284        Município   Fortaleza   2304400  CE
# 289      37369        Município     Itarema   2306553  CE
# 290      36369        Município   Itapipoca   2306405  CE
#
#                   num_pvl                                             status  \
# 0                    None                                           Deferido
# 1    PVL02.006501/2022-01                                           Deferido
# 2    PVL02.001702/2023-95                                           Deferido
# 3                    None                                           Deferido
# 4                    None                     Arquivado por decurso de prazo
# ..                    ...                                                ...
# 286  PVL02.006662/2019-91                     Arquivado por decurso de prazo
# 287  PVL02.000066/2017-36  Encaminhado à PGFN com manifestação técnica fa...
# 288                  None  Encaminhado à PGFN com manifestação técnica fa...
# 289  PVL02.006140/2019-90                                  Deferido (PVL-IF)
# 290  PVL02.003683/2019-55                                 Arquivado a pedido
#
#              num_processo        data_protocolo  \
# 0    17944.000648/2011-90  2011-08-15T03:00:00Z
# 1    17944.102546/2022-61  2022-07-26T21:47:29Z
# 2    17944.102173/2023-17  2023-05-16T17:33:18Z
# 3    17944.000090/2008-47  2008-02-20T03:00:00Z
# 4    17944.000015/2014-24  2014-11-24T02:00:00Z
# ..                    ...                   ...
# 286  17944.103714/2019-30  2019-09-27T14:12:05Z
# 287  17944.000186/2017-04  2018-10-31T13:43:46Z
# 288  17944.002003/2008-96  2010-01-14T02:00:00Z
# 289                  None                  None
# 290  17944.103296/2019-81  2019-08-30T19:43:34Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1                          Operação contratual interna
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4    Operação contratual interna (com garantia da U...
# ..                                                 ...
# 286                        Operação contratual interna
# 287  Operação contratual externa (com garantia da U...
# 288  Operação contratual externa (com garantia da U...
# 289                        Operação contratual interna
# 290                        Operação contratual interna
#
#                                          finalidade  \
# 0                                      Provias 2010
# 1                                    Infraestrutura
# 2                                    Infraestrutura
# 3                                 Caminho da Escola
# 4                PAC 2 - Mobilidade Grandes Cidades
# ..                                              ...
# 286                                  Infraestrutura
# 287                                  Infraestrutura
# 288                                  Multissetorial
# 289  Aquisição de máquinas, equipamentos e veículos
# 290                                  Infraestrutura
#
#                               tipo_credor  \
# 0         Instituição Financeira Nacional
# 1         Instituição Financeira Nacional
# 2         Instituição Financeira Nacional
# 3         Instituição Financeira Nacional
# 4         Instituição Financeira Nacional
# ..                                    ...
# 286       Instituição Financeira Nacional
# 287  Instituição Financeira Internacional
# 288  Instituição Financeira Internacional
# 289       Instituição Financeira Nacional
# 290       Instituição Financeira Nacional
#
#                                                 credor          moeda  \
# 0                                  Banco do Brasil S/A           Real
# 1                                  Banco do Brasil S/A           Real
# 2                              Caixa Econômica Federal           Real
# 3                                  Banco do Brasil S/A           Real
# 4    Banco Nacional de Desenvolvimento Econômico e ...           Real
# ..                                                 ...            ...
# 286                            Caixa Econômica Federal           Real
# 287                       Corporação Andina de Fomento  Dólar dos EUA
# 288            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 289                                Banco do Brasil S/A           Real
# 290                            Caixa Econômica Federal           Real
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    1.210000e+06                 1                      0  13/10/2011
# 1    8.000000e+06                 0                      1  28/07/2022
# 2    2.500000e+08                 0                      0  18/05/2023
# 3    1.267500e+05                 1                      0  22/02/2008
# 4    2.000000e+08                 0                      0  14/05/2015
# ..            ...               ...                    ...         ...
# 286  1.522403e+07                 0                      0  11/05/2020
# 287  1.500000e+08                 1                      0  22/11/2018
# 288  3.348200e+07                 1                      0  30/06/2009
# 289  1.000000e+06                 0                      1  29/11/2019
# 290  3.500000e+07                 0                      0  09/10/2019
#
# [291 rows x 18 columns]

# %%
# 2) Seu código aqui
df_mg = Pega_Dados_API('mg', 'estado')
df_mg["status"].value_counts()["Arquivado por decurso de prazo"]
# Out:
# 1

# %%
# 3) Seu código aqui
df_ba = Pega_Dados_API('ba', 'município')
df_ba["interessado"].value_counts().index[0]
# Out:
# 'Camaçari'

# %%
# 4) Seu código aqui
df_ba = Pega_Dados_API('ba', 'estado')
df_ba.to_csv('bahia_estado.csv')
